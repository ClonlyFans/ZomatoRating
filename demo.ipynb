# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder

# %%
TargetValueMapping().to_dict()
# Out:
# {'neg': 0, 'pos': 1}

# %%
TargetValueMapping().reverse_mapping()
# Out:
# {0: 'neg', 1: 'pos'}

# %%
df =pd.read_csv("/home/ishan/demo/Restaurant-rating-prediction/artifact/12_05_2022_22_15_37/data_ingestion/ingested/train.csv")

# %%
df.head()
# Out:
#    online_order  book_table  rate  votes  cost  listed_in(type)  \
# 0             1           0   4.0    391   750                2
# 1             0           0   0.0      0   350                4
# 2             0           0   4.0    147   700                1
# 3             1           0   3.0     19   500                2
# 4             0           0   4.0     11   800                4
#
#    listed_in(city)
# 0                0
# 1               17
# 2                9
# 3               23
# 4               23

# %%
#changing reviews with score less than 3 to be positive and vice-versa
df['rate'] = df['rate'].map(lambda x : 1 if(x > 3) else 0 )

# %%
df.head()
# Out:
#    online_order  book_table  rate  votes  cost  listed_in(type)  \
# 0             1           0     1    391   750                2
# 1             0           0     0      0   350                4
# 2             0           0     1    147   700                1
# 3             1           0     0     19   500                2
# 4             0           0     1     11   800                4
#
#    listed_in(city)
# 0                0
# 1               17
# 2                9
# 3               23
# 4               23

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30973 entries, 0 to 30972
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   online_order     30973 non-null  int64
#  1   book_table       30973 non-null  int64
#  2   rate             30973 non-null  int64
#  3   votes            30973 non-null  int64
#  4   cost             30973 non-null  int64
#  5   listed_in(type)  30973 non-null  int64
#  6   listed_in(city)  30973 non-null  int64
# dtypes: int64(7)
# memory usage: 1.7 MB

# %%
df['approx_cost(for two people)'].unique().__str__()
# Out:
# "['300' '500' '800' '700' '200' '450' '750' '550' '400' '150' '600' '650'\n '850' '900' '350' '250' '1,000' '100' '950' '1,200' '1,500' '1,300' '199'\n '80' '1,100' '160' '1,600' '130' '230' nan '1,700' '50' '190' '1,400'\n '180' '1,350' '2,200' '2,000' '1,800' '1,900' '330' '2,500' '2,100'\n '3,000' '2,800' '3,400' '40' '1,250' '4,000' '3,500' '2,400' '2,600'\n '120' '1,450' '469' '70' '3,200' '60' '560' '240' '360' '6,000' '1,050'\n '2,300' '1,650' '2,700']"

# %%
df[['online_order', 'book_table','listed_in(type)','listed_in(city)']] = df[['online_order', 'book_table','listed_in(type)','listed_in(city)']].apply(LabelEncoder().fit_transform)
df.head(5)
# Out:
#    online_order  book_table    rate  votes  \
# 0             1           0     NaN      0
# 1             0           0  3.6 /5     34
# 2             1           0   3.3/5      9
# 3             1           0   3.8/5     14
# 4             1           0     NaN      0
#
#                                 cuisines approx_cost(for two people)  \
# 0                  American, Continental                         200
# 1                         Italian, Pizza                         650
# 2                  Biryani, South Indian                         300
# 3    South Indian, North Indian, Chinese                         600
# 4  South Indian, North Indian, Beverages                         500
#
#    listed_in(type)  listed_in(city)
# 0                2               23
# 1                4               17
# 2                2               11
# 3                4                0
# 4                2               12

# %%
df = df.dropna()

# %%
df.head()
# Out:
#                                                  url  \
# 0  https://www.zomato.com/bangalore/addhuri-udupi...
# 1  https://www.zomato.com/bangalore/caf%C3%A9-dow...
# 2  https://www.zomato.com/bangalore/jalsa-banasha...
# 3  https://www.zomato.com/bangalore/penthouse-caf...
# 4  https://www.zomato.com/bangalore/woodee-pizza-...
#
#                                              address  \
# 0  1st Floor, Annakuteera, 3rd Stage, Banashankar...
# 1  12,29 Near PES University Back Gate, D'Souza N...
# 2  942, 21st Main Road, 2nd Stage, Banashankari, ...
# 3  1, 30th Main Road, 3rd Stage, Banashankari, Ba...
# 4  3353, 2nd Cross, Opposite Auden School, Hosker...
#
#                                                 name online_order book_table  \
# 0                              Addhuri Udupi Bhojana           No         No
# 1  CafÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂ© Down The A...          Yes         No
# 2                                              Jalsa          Yes        Yes
# ...

# %%
df=df.rename(columns={"approx_cost(for two people)":"cost"})
df["cost"]=df["cost"].astype(str)
df['cost'] = df['cost'].str.replace(',', '')
df['cost'] = df['cost'].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6575 entries, 1 to 7743
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   online_order     6575 non-null   int64
#  1   book_table       6575 non-null   int64
#  2   rate             6575 non-null   object
#  3   votes            6575 non-null   int64
#  4   cuisines         6575 non-null   object
#  5   cost             6575 non-null   int64
#  6   listed_in(type)  6575 non-null   int64
#  7   listed_in(city)  6575 non-null   int64
# dtypes: int64(6), object(2)
# memory usage: 462.3+ KB
